# %%
import pandas as pd
data=pd.read_csv("C:/Users/BABZMAN(ABA)/Desktop/Data sci pgg/fuel_ferc1.csv")

# %%
data=pd.DataFrame(data)
data
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
data1=data[["fuel_type_code_pudl","fuel_cost_per_unit_burned"]]
data1=data.groupby("fuel_type_code_pudl").mean()
data1
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
data2=(data["fuel_mmbtu_per_unit"].std(),data["fuel_mmbtu_per_unit"].quantile(0.75))
data2

# %%
data3=(data["fuel_qty_burned"].skew(),data["fuel_qty_burned"].kurt())
data3
# Out:
# (15.851495469109503, 651.3694501337732)

# %%
data.isnull().sum()
percent=180/(data.shape[0])

# %%
import seaborn as sns
import matplotlib.pyplot as plt
red_d=data.iloc[:,6:]
plt.figure(figsize=(10,8))
sns.heatmap(red_d)

# %%
data4=data[data["fuel_type_code_pudl"]=="coal"]
data41=data4[data4["report_year"]==1998]
data42=data4[data4["report_year"]==1994]
data41=data41.groupby("report_year").mean()
data42=data41.groupby("report_year").mean()
ans=data41["fuel_cost_per_unit_burned"]-data42["fuel_cost_per_unit_burned"]
ans=ans/data42["fuel_cost_per_unit_burned"]
data41
# Out:
#              utility_id_ferc1  fuel_qty_burned  fuel_mmbtu_per_unit  \
# report_year
# 1998               107.663573     2.084013e+06            21.375364
#
#              fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# report_year
# 1998                         27.616234                    716.015659
#
#              fuel_cost_per_mmbtu
# report_year
# 1998                    1.292496

# %%
data5=data.groupby(["fuel_type_code_pudl","report_year"]).mean()
data5[40:77]
# Out:
#                                  utility_id_ferc1  fuel_qty_burned  \
# fuel_type_code_pudl report_year
# gas                 2009               121.705495     4.188303e+06
#                     2010               123.775304     4.556332e+06
#                     2011               124.470348     4.791139e+06
#                     2012               125.908714     5.710269e+06
#                     2013               126.556503     5.559273e+06
#                     2014               127.230769     5.365575e+06
#                     2015               136.410256     6.570167e+06
#                     2016               138.461538     6.977883e+06
#                     2017               134.743875     6.287027e+06
#                     2018               134.971111     7.724773e+06
# nuclear             1994                93.563380     2.914601e+06
#                     1995                96.904110     2.813809e+06
# ...
